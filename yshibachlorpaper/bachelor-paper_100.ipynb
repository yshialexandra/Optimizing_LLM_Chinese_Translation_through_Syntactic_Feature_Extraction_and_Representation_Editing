# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

# %%
# stanza pipeline for constituency and dependency parsing
import stanza
nlp = stanza.Pipeline('zh')

# %%
 # functions and data structures for feature extraction
from collections import defaultdict
import xml.etree.ElementTree as ET
import os
from tqdm import tqdm
import json
import random
#构造嵌套字典
def tree():
    return defaultdict(tree)
#去掉空格
def split_string(text):
    result = []
    tmp = ""
    flag = 0
    for char in text:
        if char == ' ':
            flag = 0
            if tmp != "":
                result.append(tmp)
                tmp = ""
            continue
        elif char == '(':
            flag = 1
            result.append(char)
            continue
        elif char == ')':
            result.append(char)
            continue
        elif flag == 1:
            tmp += char
            continue
    return result, ''.join(result)

class Stack:
    def __init__(self):
        self.items = []

    def is_empty(self):
        return self.items == []

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            print("Stack is empty")

    def top(self):
        if not self.is_empty():
            return self.items[-1]
        else:
            print("Stack is empty")

    def size(self):
        return len(self.items)

#将递归的 defaultdict 转换为普通的嵌套字典。
def dicts(t): return {k: dicts(t[k]) for k in t}

def build_constituency_feature_tree(text, MAXLAYER=3):
    treeStrList, tmp = split_string(text)
    featureTree = tree()
    stack = Stack()
    i = 0
    layer = -1
    while i < len(treeStrList):
        if treeStrList[i] == '(':
            i+=1
            layer+=1
            if layer <= MAXLAYER:
                if(stack.is_empty()):
                    featureTree[treeStrList[i]]
                    stack.push(featureTree[treeStrList[i]])
                else:
                    if(treeStrList[i] in stack.top()):
                        keytmp = treeStrList[i] + str(random.randint(1, 100000)) #发现重复键，则附加随机数
                    else:
                        keytmp = treeStrList[i]
                    stack.top()[keytmp]
                    stack.push(stack.top()[keytmp])
            i+=1
            continue
        if treeStrList[i] == ')':
            if layer > 0 and layer <= MAXLAYER:
                stack.pop()
            layer-=1
            i+=1
            continue
    return dicts(featureTree)['ROOT']

def extract_constituency_feature_from_tree(feature_tree):
    queue = []
    result = []
    queue.append(feature_tree)
    while len(queue) > 0:
        tmp = queue.pop()
        for key in tmp.keys():
            if isinstance(tmp[key], dict) and len(tmp[key]) > 0:
                queue.append(tmp[key])
                # 去除数字
                result.append(''.join(char for char in str({key: tmp[key]}) if not char.isdigit()))
    return result

# zcy fix return type, Time: 2025.01.16
def extract_dependency_feature_from_list(words):
    sent_list = []
    for word in words:
        head_id = word.head
        head_upos = "ROOT" if head_id == 0 else words[head_id - 1].upos  # 获取 head 的 UPOS
        pos_list = [word.upos, head_upos, word.deprel]
        head_lemma = "NONE" if head_id == 0 else words[head_id - 1].lemma
        lex_list = [word.lemma, head_lemma, word.deprel]
        sent_list.append([f'{pos_list}', f'{lex_list}'])
    return sent_list

def parse_tmx(file):
    # 解析 XML 文件
    tree = ET.parse(file)
    root = tree.getroot()

    # 找到 TMX 文件中的 body 部分
    body = root.find("body")
    if body is None:
        raise ValueError("Invalid TMX file: missing <body> section.")

    # 遍历所有 <tu> 元素
    for tu in body.findall("tu"):
        translations = {}
        # 提取每个 <tu> 中的 <tuv> 元素
        for tuv in tu.findall("tuv"):
            lang = tuv.attrib.get("{http://www.w3.org/XML/1998/namespace}lang")  # 获取语言属性
            seg = tuv.find("seg")
            if lang and seg is not None:
                translations[lang] = seg.text.strip()

        # 如果有源语言和目标语言，返回一对
        if "en-US" in translations and "zh-CN" in translations:
            yield translations["en-US"], translations["zh-CN"]

def list_txt_files(folder_path):
    result = []
    # 遍历文件夹及其子文件夹中的所有文件
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.txt'):  # 只处理以 .txt 结尾的文件
                file_path = os.path.join(root, file)
                result.append(file_path)  # 返回文件的完整路径
    return result

# %%
#删除原创汉语语料库部分内容，确保翻译语料库和原创汉语语料库字数大体相等
# 读取原创汉语语料库的两个字典,
with open('orig_constituency_feature_count.json', 'r', encoding='utf-8') as f:
    orig_constituency_feature_count = json.load(f)
with open('./orig_dependency_feature_count.json', 'r', encoding='utf-8') as f:
    orig_dependency_feature_count = json.load(f)
length = len(list_txt_files("./delete"))
for file in tqdm(list_txt_files("./delete"), total=length, desc="Processing", unit="file"):
    with open(file, "r", encoding="utf-8") as file:
        for line in file:
            if line == '\n':
                continue
            doc = nlp(line)
            # Constituency
            m = str(doc.sentences[0].constituency)
            layer_2_feature_tree = build_constituency_feature_tree(m, 2)
            sec_feature_list = extract_constituency_feature_from_tree(layer_2_feature_tree)
            for i in sec_feature_list:
                orig_constituency_feature_count[i] -= 1
            
            layer_3_feature_tree = build_constituency_feature_tree(m, 3)
            sec_feature_list = extract_constituency_feature_from_tree(layer_3_feature_tree)
            for i in sec_feature_list:
                orig_constituency_feature_count[i] -= 1
           
            # Dependency
            words = doc.sentences[0].words
            dependency_list = extract_dependency_feature_from_list(words)
            for dep in dependency_list:
                orig_dependency_feature_count[dep[0]] -= 1
sorted_const_data = dict(sorted(orig_constituency_feature_count.items(), key=lambda item: item[1], reverse=True))

sorted_dep_data = dict(sorted(orig_dependency_feature_count.items(), key=lambda item: item[1], reverse=True))

with open(f'./orig_constituency_feature_count_delete.json', 'w', encoding='utf-8') as f:
    json.dump(sorted_const_data, f, ensure_ascii=False, indent=4)
with open(f'./orig_dependency_feature_count_delete.json', 'w', encoding='utf-8') as f:
    json.dump(sorted_dep_data, f, ensure_ascii=False, indent=4)
# Out:
# Processing: 100%|██████████| 4/4 [09:13<00:00, 138.45s/file]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#orig calculate dep and const feature
#sy
#计算原创语料库的Constituency和Dependency特征，并统计全体特征数量，写入json文件
Constituency_feature_count_map = defaultdict(int)
Dependency_feature_count_map = defaultdict(int)
for file in tqdm(list_txt_files("./LCMC_txt"), total=88, desc="Processing", unit="file"):
    with open(file, "r", encoding="utf-8") as file:
        for line in file:
            if line == '\n':
                continue
            doc = nlp(line)
            # Constituency
            m = str(doc.sentences[0].constituency)
            layer_2_feature_tree = build_constituency_feature_tree(m, 2)
            sec_feature_list = extract_constituency_feature_from_tree(layer_2_feature_tree)
            for i in sec_feature_list:
                Constituency_feature_count_map[i] += 1
            
            layer_3_feature_tree = build_constituency_feature_tree(m, 3)
            sec_feature_list = extract_constituency_feature_from_tree(layer_3_feature_tree)
            for i in sec_feature_list:
                Constituency_feature_count_map[i] += 1
           
            # Dependency
            words = doc.sentences[0].words
            dependency_list = extract_dependency_feature_from_list(words)
            for dep in dependency_list:
                Dependency_feature_count_map[dep[0]] += 1
sorted_const_data = dict(sorted(Constituency_feature_count_map.items(), key=lambda item: item[1], reverse=True))

sorted_dep_data = dict(sorted(Dependency_feature_count_map.items(), key=lambda item: item[1], reverse=True))

with open(f'./orig_constituency_feature_count.json', 'w', encoding='utf-8') as f:
    json.dump(sorted_const_data, f, ensure_ascii=False, indent=4)
with open(f'./orig_dependency_feature_count.json', 'w', encoding='utf-8') as f:
    json.dump(sorted_dep_data, f, ensure_ascii=False, indent=4)

# %%
#上一步手动将orig的const和dep feature中出现次数大于5的复制到json中，修改json文件名为orig_all_feature.json
#sy

# %%
#combined_all_feature.json
#orig和ins去重+放到同一个字典里，key是feature，value是index
all_feature = {}
with open('./orig_all_feature.json', 'r', encoding='utf-8') as f:
    data = json.load(f)
    all_feature.update(data)
with open('./ins_all_feature.json', 'r', encoding='utf-8') as f:
    data = json.load(f)
    all_feature.update(data)

for index,key in enumerate(all_feature.keys()):
    all_feature[key] = index

with open('./combined_all_feature.json', 'w', encoding='utf-8') as f:
    json.dump(all_feature, f, ensure_ascii=False, indent=4)

# %%
#combined_all_feature_delete.json
#orig和ins去重+放到同一个字典里，key是feature，value是index
all_feature = {}
with open('./orig_all_feature_delete.json', 'r', encoding='utf-8') as f:
    data = json.load(f)
    all_feature.update(data)
with open('./ins_all_feature.json', 'r', encoding='utf-8') as f:
    data = json.load(f)
    all_feature.update(data)

for index,key in enumerate(all_feature.keys()):
    all_feature[key] = index

with open('./combined_all_feature_delete.json', 'w', encoding='utf-8') as f:
    json.dump(all_feature, f, ensure_ascii=False, indent=4)

# %%
#vector
build_feature_vec = {}
with open('./combined_all_feature.json', 'r', encoding='utf-8') as f:
    combined_all_feature = json.load(f)

x = []
y = []
#go through sentences in LCMC, build feature vector
orig_length = len(list_txt_files("./LCMC_txt"))
for file in tqdm(list_txt_files("./LCMC_txt"), total=orig_length, desc="Processing", unit="file"):
    with open(file, "r", encoding="utf-8") as file:
        for line in file:
            if line == "":
                continue
            doc = nlp(line)
            sent_vec = [0] * len(combined_all_feature)
            #constituency
            m = str(doc.sentences[0].constituency)
            result = build_constituency_feature_tree(m, 2)
            ff = extract_constituency_feature_from_tree(result)
            for item in ff:
                if item in combined_all_feature.keys():
                    sent_vec[combined_all_feature[item]] += 1
            result = build_constituency_feature_tree(m, 3)
            ff = extract_constituency_feature_from_tree(result)
            for item in ff:
                if item in combined_all_feature.keys():
                    sent_vec[combined_all_feature[item]] += 1
            #dependency
            m = doc.sentences[0].words
            result = extract_dependency_feature_from_list(m)
            for item in result:
                if item[0] in combined_all_feature.keys():
                    sent_vec[combined_all_feature[item[0]]] += 1
            x.append(sent_vec)
            y.append(0)

#go through sentences in insructed txt, build feature vector
translated_length = len(list_txt_files("./instruct_txt"))
for file in tqdm(list_txt_files("./instruct_txt"), total=translated_length, desc="Processing", unit="file"):
    with open(file, "r", encoding="utf-8") as file:
        for line in file:
            if line == "":
                continue
            doc = nlp(line)
            sent_vec = [0] * len(combined_all_feature)
            #constituency
            m = str(doc.sentences[0].constituency)
            result = build_constituency_feature_tree(m, 2)
            ff = extract_constituency_feature_from_tree(result)
            for item in ff:
                if item in combined_all_feature.keys():
                    sent_vec[combined_all_feature[item]] += 1
            result = build_constituency_feature_tree(m, 3)
            ff = extract_constituency_feature_from_tree(result)
            for item in ff:
                if item in combined_all_feature.keys():
                    sent_vec[combined_all_feature[item]] += 1
            #dependency
            m = doc.sentences[0].words
            result = extract_dependency_feature_from_list(m)
            for item in result:
                if item[0] in combined_all_feature.keys():
                    sent_vec[combined_all_feature[item[0]]] += 1
            x.append(sent_vec)
            y.append(1)

with open('./x.txt', 'w', encoding='utf-8') as f:
    for item in x:
        f.write(f"{item}\n")
with open('./y.txt', 'w', encoding='utf-8') as f:
    for item in y:
        f.write(f"{item}\n")
# Out:
# Processing: 100%|██████████| 3/3 [21:19<00:00, 426.51s/file]
# Processing:   0%|          | 0/3 [00:00<?, ?file/s]

# %%
#deleted vector
build_feature_vec = {}
with open('./combined_all_feature_delete.json', 'r', encoding='utf-8') as f:
    combined_all_feature = json.load(f)

x = []
y = []
#go through sentences in LCMC, build feature vector
orig_length = len(list_txt_files("./LCMC_txt"))
for file in tqdm(list_txt_files("./LCMC_txt"), total=orig_length, desc="Processing", unit="file"):
    with open(file, "r", encoding="utf-8") as file:
        for line in file:
            if line == "":
                continue
            doc = nlp(line)
            sent_vec = [0] * len(combined_all_feature)
            #constituency
            m = str(doc.sentences[0].constituency)
            result = build_constituency_feature_tree(m, 2)
            ff = extract_constituency_feature_from_tree(result)
            for item in ff:
                if item in combined_all_feature.keys():
                    sent_vec[combined_all_feature[item]] += 1
            result = build_constituency_feature_tree(m, 3)
            ff = extract_constituency_feature_from_tree(result)
            for item in ff:
                if item in combined_all_feature.keys():
                    sent_vec[combined_all_feature[item]] += 1
            #dependency
            m = doc.sentences[0].words
            result = extract_dependency_feature_from_list(m)
            for item in result:
                if item[0] in combined_all_feature.keys():
                    sent_vec[combined_all_feature[item[0]]] += 1
            x.append(sent_vec)
            y.append(0)

#go through sentences in insructed txt, build feature vector
translated_length = len(list_txt_files("./instruct_txt"))
for file in tqdm(list_txt_files("./instruct_txt"), total=translated_length, desc="Processing", unit="file"):
    with open(file, "r", encoding="utf-8") as file:
        for line in file:
            if line == "":
                continue
            doc = nlp(line)
            sent_vec = [0] * len(combined_all_feature)
            #constituency
            m = str(doc.sentences[0].constituency)
            result = build_constituency_feature_tree(m, 2)
            ff = extract_constituency_feature_from_tree(result)
            for item in ff:
                if item in combined_all_feature.keys():
                    sent_vec[combined_all_feature[item]] += 1
            result = build_constituency_feature_tree(m, 3)
            ff = extract_constituency_feature_from_tree(result)
            for item in ff:
                if item in combined_all_feature.keys():
                    sent_vec[combined_all_feature[item]] += 1
            #dependency
            m = doc.sentences[0].words
            result = extract_dependency_feature_from_list(m)
            for item in result:
                if item[0] in combined_all_feature.keys():
                    sent_vec[combined_all_feature[item[0]]] += 1
            x.append(sent_vec)
            y.append(1)

with open('./x_delete.txt', 'w', encoding='utf-8') as f:
    for item in x:
        f.write(f"{item}\n")
with open('./y_delete.txt', 'w', encoding='utf-8') as f:
    for item in y:
        f.write(f"{item}\n")
# Out:
# Processing: 100%|██████████| 3/3 [21:28<00:00, 429.47s/file]
# Processing: 100%|██████████| 88/88 [11:01<00:00,  7.52s/file]

# %%
# 读取文件内容
with open("x.txt", "r") as file:
    content = file.read()

# 去掉多余字符（如方括号和换行符），将字符串转换为二维列表
content = content.replace('[', '').replace(']', '').strip()
data = [list(map(int, row.split(','))) for row in content.split('\n')]
# 转换为 NumPy 数组
x = np.array(data)
# 读取文件内容
with open("y.txt", "r") as file:
    content = file.readlines()

# 去掉换行符并转换为整数
y = np.array([int(line.strip()) for line in content])

# %%
# 读取 delete 文件内容
with open("x_delete.txt", "r") as file:
    content = file.read()

# 去掉多余字符（如方括号和换行符），将字符串转换为二维列表
content = content.replace('[', '').replace(']', '').strip()
data = [list(map(int, row.split(','))) for row in content.split('\n')]
# 转换为 NumPy 数组
x = np.array(data)
# 读取文件内容
with open("y_delete.txt", "r") as file:
    content = file.readlines()

# 去掉换行符并转换为整数
y = np.array([int(line.strip()) for line in content])

# %%
# 对于二维数组 x（假设每行是一个样本）
x = x[:, 327:]  # 保留从第300行开始的所有行，所有列

# %%
print(x.shape)
print(y.shape)
# Out:
# (11074, 511)
# (11074,)

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)
# 创建模型
clf = RandomForestClassifier(n_estimators=511, random_state=42)
for fold, (train_index, test_index) in enumerate(kf.split(x)):
    X_train, X_test = x[train_index], x[test_index]
    y_train, y_test = y[train_index], y[test_index]

    clf.fit(X_train, y_train)
    score = clf.score(X_test, y_test)
    print(f"第 {fold+1} 折准确率: {score:.4f}")
# Out:
# 第 1 折准确率: 0.7747
# 第 2 折准确率: 0.7765
# 第 3 折准确率: 0.7842
# 第 4 折准确率: 0.7666
# 第 5 折准确率: 0.7638

# %%
# 读取字典
with open('./combined_all_feature_delete.json', 'r', encoding='utf-8') as f:
    feature_names = json.load(f)
# 反转字典：交换 key 和 value
reversed_dict = {v: k for k, v in feature_names.items()}

# %%
# 提取特征重要性
importances = clf.feature_importances_
indices = np.argsort(importances)[::-1]

# 打印特征重要性
print("特征重要性排名：")
for i in indices:
    print(f"{reversed_dict[i+327]}: {importances[i]:.4f}")

# 可视化
plt.figure(figsize=(8, 6))
plt.bar(range(10), importances[indices][:10], align='center', alpha=0.7)
plt.xticks(range(10), [reversed_dict[i+327] for i in indices[:10]], rotation=45)
plt.xlabel('特征名称')
plt.ylabel('重要性得分')
plt.title('特征重要性')
plt.tight_layout()
plt.show()
# Out:
# 特征重要性排名：
# ['VERB', 'VERB', 'advcl']: 0.0293
# ['PRON', 'VERB', 'nsubj']: 0.0274
# ['NOUN', 'NOUN', 'nmod']: 0.0270
# ['PUNCT', 'VERB', 'punct']: 0.0237
# ['NOUN', 'VERB', 'obj']: 0.0229
# ['NUM', 'NOUN', 'nummod']: 0.0214
# ['ADV', 'VERB', 'advmod']: 0.0189
# ['NOUN', 'VERB', 'nsubj']: 0.0183
# ['PUNCT', 'NOUN', 'punct']: 0.0183
# ['ADP', 'NOUN', 'case']: 0.0178
# ['DET', 'NOUN', 'det']: 0.0175
# ['AUX', 'VERB', 'aux']: 0.0174
# ['X', 'X', 'flat:foreign']: 0.0163
# ['ADV', 'VERB', 'mark']: 0.0155
# ['VERB', 'VERB', 'xcomp']: 0.0144
# ['VERB', 'VERB', 'ccomp']: 0.0140
# ['ADJ', 'NOUN', 'amod']: 0.0139
# ['PROPN', 'NOUN', 'nmod']: 0.0136
# ['NOUN', 'NOUN', 'clf']: 0.0135
# ['PART', 'NOUN', 'case']: 0.0131
# ['PART', 'VERB', 'mark:rel']: 0.0126
# ['NOUN', 'VERB', 'obl']: 0.0123
# ['X', 'VERB', 'nsubj']: 0.0114
# ['PART', 'ADJ', 'mark:rel']: 0.0113
# ['VERB', 'NOUN', 'acl:relcl']: 0.0113
# ['PUNCT', 'PROPN', 'punct']: 0.0112
# {'IP': {'NP': {}, 'VP': {}, '.': {}, "''": {}}}: 0.0111
# ['X', 'NOUN', 'nmod']: 0.0101
# ['PROPN', 'VERB', 'nsubj']: 0.0099
# ['VERB', 'VERB', 'mark']: 0.0090
# ['NOUN', 'PART', 'compound']: 0.0090
# ['PART', 'PRON', 'case']: 0.0088
# ['VERB', 'PART', 'compound']: 0.0087
# ['PROPN', 'PROPN', 'flat:name']: 0.0087
# ['CCONJ', 'NOUN', 'cc']: 0.0085
# ['NOUN', 'NOUN', 'conj']: 0.0084
# ['VERB', 'VERB', 'parataxis']: 0.0084
# ['NOUN', 'VERB', 'nmod:tmod']: 0.0082
# ['ADV', 'ADJ', 'advmod']: 0.0077
# ['PRON', 'NOUN', 'det']: 0.0075
# ['PROPN', 'PART', 'compound']: 0.0073
# ['NOUN', 'PART', 'nmod']: 0.0068
# ['PART', 'NOUN', 'nmod']: 0.0068
# ['PART', 'PROPN', 'case']: 0.0067
# ['PART', 'VERB', 'nsubj']: 0.0066
# ['ADP', 'VERB', 'case']: 0.0066
# ['PUNCT', 'ADJ', 'punct']: 0.0064
# ['PART', 'VERB', 'discourse']: 0.0064
# ['AUX', 'NOUN', 'cop']: 0.0063
# ['PART', 'VERB', 'obj']: 0.0063
# ['AUX', 'VERB', 'aux:pass']: 0.0061
# ['PUNCT', 'ADV', 'punct']: 0.0060
# ['NOUN', 'ADJ', 'nsubj']: 0.0058
# ['CCONJ', 'PROPN', 'cc']: 0.0057
# ['PROPN', 'VERB', 'obj']: 0.0057
# ['PRON', 'NOUN', 'nmod']: 0.0054
# ['ADJ', 'VERB', 'xcomp']: 0.0053
# ['ADP', 'VERB', 'mark']: 0.0051
# ['PUNCT', 'PART', 'punct']: 0.0046
# ['ADP', 'PRON', 'case']: 0.0044
# ['VERB', 'ROOT', 'root']: 0.0043
# ['X', 'NOUN', 'appos']: 0.0042
# ['PROPN', 'PART', 'nmod']: 0.0039
# ['PRON', 'VERB', 'obj']: 0.0038
# ['VERB', 'VERB', 'conj']: 0.0038
# ['ADP', 'PART', 'case']: 0.0037
# ['ADJ', 'VERB', 'ccomp']: 0.0037
# ['ADJ', 'PART', 'amod']: 0.0035
# ['ADJ', 'VERB', 'advcl']: 0.0034
# ['PRON', 'NOUN', 'nsubj']: 0.0034
# ['PRON', 'VERB', 'obl']: 0.0033
# ['NOUN', 'NOUN', 'acl']: 0.0032
# ['ADP', 'PROPN', 'case']: 0.0032
# ['NOUN', 'NOUN', 'nsubj']: 0.0032
# ['PUNCT', 'X', 'punct']: 0.0031
# ['X', 'VERB', 'obj']: 0.0031
# ['PROPN', 'NOUN', 'compound']: 0.0030
# ['PROPN', 'NOUN', 'appos']: 0.0030
# ['ADV', 'ADJ', 'mark']: 0.0030
# ['NOUN', 'ADJ', 'nmod']: 0.0030
# ['ADV', 'NOUN', 'advmod']: 0.0030
# ['PROPN', 'PROPN', 'conj']: 0.0028
# ['CCONJ', 'PART', 'cc']: 0.0028
# ['NOUN', 'ROOT', 'root']: 0.0027
# ['VERB', 'NOUN', 'amod']: 0.0027
# ['ADJ', 'VERB', 'advmod']: 0.0026
# ['NOUN', 'VERB', 'ccomp']: 0.0026
# ['CCONJ', 'VERB', 'cc']: 0.0026
# ['ADV', 'NOUN', 'mark']: 0.0026
# {'NP': {'CD': {}, 'NNB': {}}}: 0.0025
# ['ADJ', 'PART', 'compound']: 0.0025
# ['PART', 'PART', 'case']: 0.0025
# ['PART', 'VERB', 'obl']: 0.0025
# ['PROPN', 'VERB', 'obl']: 0.0025
# ['PART', 'NOUN', 'mark:rel']: 0.0024
# ['NOUN', 'VERB', 'obl:patient']: 0.0024
# {'NP': {'NNP': {}, '/': {}, 'NNP': {}}}: 0.0023
# ['NUM', 'VERB', 'obj']: 0.0023
# {'NP': {'FW': {}}}: 0.0023
# ['NOUN', 'VERB', 'nsubj:pass']: 0.0023
# ['PART', 'ADJ', 'mark:adv']: 0.0022
# ['X', 'PROPN', 'appos']: 0.0022
# ['PART', 'ADJ', 'discourse']: 0.0022
# ['ADJ', 'ROOT', 'root']: 0.0022
# ['VERB', 'PART', 'acl:relcl']: 0.0021
# ['PART', 'NOUN', 'conj']: 0.0021
# ['NOUN', 'NOUN', 'appos']: 0.0021
# ['NUM', 'PART', 'nummod']: 0.0020
# ['NOUN', 'VERB', 'advcl']: 0.0020
# ['VERB', 'VERB', 'csubj']: 0.0020
# ['AUX', 'ADJ', 'cop']: 0.0019
# {'IP': {'IP': {}, ',': {}, "''": {}, 'NP': {}, 'VP': {}, '.': {}}}: 0.0019
# ['PART', 'DET', 'case']: 0.0019
# ['PRON', 'ADJ', 'nsubj']: 0.0018
# ['PART', 'PART', 'compound']: 0.0018
# ['ADJ', 'ADJ', 'advcl']: 0.0018
# ['ADJ', 'NOUN', 'acl:relcl']: 0.0018
# ['AUX', 'ADJ', 'aux']: 0.0017
# ['X', 'PART', 'appos']: 0.0017
# ['PART', 'PRON', 'mark:rel']: 0.0017
# ['PART', 'PART', 'nmod']: 0.0016
# ['PUNCT', 'PRON', 'punct']: 0.0016
# ['VERB', 'ADJ', 'advcl']: 0.0016
# ['ADJ', 'VERB', 'parataxis']: 0.0016
# ['ADP', 'ADJ', 'case']: 0.0016
# ['AUX', 'VERB', 'cop']: 0.0016
# ['PROPN', 'PROPN', 'nmod']: 0.0015
# {'IP': {'NP': {'NNP': {}}, 'VP': {'ADVP': {}, 'VP': {}}, '.': {}}}: 0.0015
# ['NOUN', 'VERB', 'parataxis']: 0.0015
# ['NOUN', 'PART', 'conj']: 0.0014
# {'IP': {'IP': {}, ',': {}, 'PP': {}, '.': {}}}: 0.0014
# ['VERB', 'NOUN', 'parataxis']: 0.0014
# ['PROPN', 'NOUN', 'nsubj']: 0.0014
# {'IP': {'``': {}, 'NP': {}, 'VP': {}, '.': {}, "''": {}}}: 0.0014
# ['DET', 'PART', 'det']: 0.0014
# ['NOUN', 'PROPN', 'nmod']: 0.0014
# ['NUM', 'VERB', 'obl']: 0.0014
# ['PROPN', 'ROOT', 'root']: 0.0013
# ['PART', 'ADJ', 'nsubj']: 0.0013
# ['ADV', 'ADV', 'advmod']: 0.0013
# ['ADJ', 'ADJ', 'conj']: 0.0013
# {'IP': {'CP': {}, ',': {}, 'NP': {}, 'VP': {}, '.': {}}}: 0.0013
# ['VERB', 'ADJ', 'parataxis']: 0.0012
# {'IP': {'``': {}, 'NP': {}, 'VP': {}, '.': {}}}: 0.0012
# ['AUX', 'PART', 'cop']: 0.0012
# {'IP': {'CP': {}, ',': {}, 'ADVP': {}, 'NP': {}, 'VP': {}, '.': {}}}: 0.0012
# ['PUNCT', 'NUM', 'punct']: 0.0012
# ['DET', 'VERB', 'nmod:tmod']: 0.0012
# ['NOUN', 'VERB', 'iobj']: 0.0011
# ['NOUN', 'PROPN', 'conj']: 0.0011
# ['NOUN', 'ADJ', 'obl']: 0.0011
# ['VERB', 'NOUN', 'csubj']: 0.0011
# {'IP': {'NP': {'NNP': {}}, 'VP': {'VV': {}, ',': {}, 'IP': {}}, '.': {}}}: 0.0011
# ['NOUN', 'PROPN', 'appos']: 0.0011
# ['AUX', 'NOUN', 'aux']: 0.0011
# ['NOUN', 'NUM', 'nmod']: 0.0011
# ['NUM', 'NOUN', 'nmod']: 0.0010
# ['ADP', 'VERB', 'xcomp']: 0.0010
# ['ADP', 'X', 'case']: 0.0010
# ['NOUN', 'NOUN', 'nummod']: 0.0010
# ['PART', 'NOUN', 'discourse']: 0.0010
# ['PART', 'NUM', 'mark:rel']: 0.0010
# ['VERB', 'NOUN', 'acl']: 0.0010
# ['PROPN', 'PART', 'appos']: 0.0010
# ['AUX', 'NUM', 'cop']: 0.0010
# ['ADJ', 'VERB', 'csubj']: 0.0010
# ['PRON', 'VERB', 'nsubj:pass']: 0.0009
# ['CCONJ', 'ADJ', 'cc']: 0.0009
# {'IP': {'NP': {'CP': {}, 'NP': {}}, 'VP': {'ADVP': {}, 'VP': {}}, '.': {}}}: 0.0009
# ['PART', 'PART', 'conj']: 0.0009
# ['X', 'VERB', 'obl']: 0.0009
# ['PRON', 'PART', 'det']: 0.0009
# ['PART', 'VERB', 'mark:adv']: 0.0009
# ['PRON', 'VERB', 'obl:patient']: 0.0009
# ['DET', 'VERB', 'nsubj']: 0.0008
# ['NOUN', 'NOUN', 'acl:relcl']: 0.0008
# ['VERB', 'NOUN', 'conj']: 0.0008
# ['NOUN', 'X', 'nmod']: 0.0008
# ['NOUN', 'ADJ', 'nmod:tmod']: 0.0008
# ['PRON', 'PART', 'nmod']: 0.0008
# ['NOUN', 'VERB', 'xcomp']: 0.0008
# ['PART', 'NOUN', 'nsubj']: 0.0008
# ['PART', 'PART', 'mark:rel']: 0.0008
# {'NP': {'CD': {}, 'NNB': {}, 'CD': {}, 'NNB': {}}}: 0.0007
# ['NOUN', 'PART', 'nsubj']: 0.0007
# ['NOUN', 'PROPN', 'nmod:tmod']: 0.0007
# {'IP': {'NP': {'NNP': {}}, 'VP': {'VC': {}, 'NP': {}}, '.': {}}}: 0.0007
# ['PROPN', 'X', 'nmod']: 0.0007
# ['PROPN', 'ADJ', 'nmod']: 0.0007
# {'IP': {'IP': {'ADVP': {}, 'NP': {}, 'VP': {}}, ',': {}, 'IP': {'NP': {}, 'VP': {}}, '.': {}}}: 0.0007
# {'NP': {'-LRB-': {}, 'DNP': {}, 'NP': {}, '-RRB-': {}}}: 0.0007
# ['AUX', 'PROPN', 'cop']: 0.0007
# ['NOUN', 'PART', 'acl']: 0.0006
# ['ADV', 'PRON', 'mark']: 0.0006
# ['NUM', 'NUM', 'nummod']: 0.0006
# {'IP': {'NP': {'DP': {}, 'NP': {}}, 'VP': {'VP': {}, ',': {}, 'VP': {}}, '.': {}}}: 0.0006
# ['PART', 'ROOT', 'root']: 0.0006
# ['NOUN', 'PRON', 'nsubj']: 0.0006
# ['ADV', 'NUM', 'advmod']: 0.0006
# ['VERB', 'PROPN', 'acl:relcl']: 0.0006
# ['PRON', 'PART', 'appos']: 0.0006
# ['DET', 'NUM', 'det']: 0.0006
# ['PART', 'VERB', 'ccomp']: 0.0006
# ['PROPN', 'ADJ', 'nsubj']: 0.0006
# ['PRON', 'ADJ', 'nmod']: 0.0006
# ['NOUN', 'NOUN', 'parataxis']: 0.0006
# ['AUX', 'PRON', 'cop']: 0.0006
# ['NOUN', 'ADJ', 'conj']: 0.0006
# ['X', 'PART', 'nmod']: 0.0006
# ['NOUN', 'NOUN', 'nmod:tmod']: 0.0006
# ['ADP', 'NUM', 'case']: 0.0006
# {'IP': {'NP': {'PRD': {}}, 'VP': {'ADVP': {}, 'VP': {}}, '.': {}}}: 0.0006
# ['PRON', 'PRON', 'appos']: 0.0006
# ['NOUN', 'ADJ', 'obj']: 0.0006
# ['NUM', 'VERB', 'nsubj']: 0.0005
# ['PRON', 'NOUN', 'appos']: 0.0005
# ['NOUN', 'PART', 'appos']: 0.0005
# ['VERB', 'ADJ', 'xcomp']: 0.0005
# {'IP': {'NP': {'DNP': {}, 'NP': {}}, 'VP': {'VC': {}, 'NP': {}}, '.': {}}}: 0.0005
# ['PART', 'VERB', 'compound:ext']: 0.0005
# ['NOUN', 'PROPN', 'acl']: 0.0005
# ['PART', 'ADP', 'mark:rel']: 0.0005
# {'IP': {'IP': {}, ',': {}, 'IP': {}, '.': {}, "''": {}}}: 0.0005
# ['PART', 'PROPN', 'conj']: 0.0005
# ['DET', 'VERB', 'obl']: 0.0005
# ['PART', 'ADJ', 'nmod']: 0.0005
# ['VERB', 'ADJ', 'mark']: 0.0005
# ['VERB', 'X', 'acl:relcl']: 0.0005
# {'VP': {'ADVP': {}, 'PP': {}, 'ADVP': {}, 'VP': {}}}: 0.0005
# ['VERB', 'ADJ', 'conj']: 0.0005
# {'IP': {'NP': {'PRP': {}}, 'VP': {'VV': {}, ':': {}, 'IP': {}}, '.': {}, "''": {}}}: 0.0005
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ',': {}, 'IP': {'ADVP': {}, 'ADVP': {}, 'NP': {}, 'VP': {}}, '.': {}}}: 0.0005
# ['VERB', 'ADP', 'ccomp']: 0.0005
# ['VERB', 'ADJ', 'ccomp']: 0.0005
# ['PRON', 'PART', 'nsubj']: 0.0005
# ['VERB', 'ADJ', 'csubj']: 0.0005
# {'IP': {'ADVP': {}, ',': {}, 'IP': {}, '.': {}}}: 0.0005
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ',': {}, 'RB': {}, 'IP': {'NP': {}, 'VP': {}}, '.': {}}}: 0.0005
# ['PUNCT', 'AUX', 'punct']: 0.0004
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ',': {}, 'IP': {'ADVP': {}, 'VP': {}}, '.': {}}}: 0.0004
# ['PROPN', 'NOUN', 'conj']: 0.0004
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ',': {}, 'PP': {'IN': {}, 'IP': {}}, '.': {}}}: 0.0004
# {'IP': {'IP': {'VP': {}}, ',': {}, 'NP': {'DNP': {}, 'NP': {}}, 'VP': {'ADVP': {}, 'VP': {}}, '.': {}}}: 0.0004
# ['PROPN', 'VERB', 'obl:patient']: 0.0004
# ['VERB', 'VERB', 'obj']: 0.0004
# ['PROPN', 'PROPN', 'appos']: 0.0004
# ['CCONJ', 'NUM', 'cc']: 0.0004
# {'NP': {'NN': {}, 'SFN': {}, 'SFN': {}}}: 0.0004
# ['ADJ', 'VERB', 'conj']: 0.0004
# ['ADV', 'PART', 'advmod']: 0.0004
# ['PART', 'NOUN', 'acl:relcl']: 0.0004
# {'IP': {'NP': {'PRP': {}}, 'VP': {'VP': {}, ',': {}, 'RB': {}, 'VP': {}}, '.': {}}}: 0.0004
# {'IP': {'NP': {'DP': {}, 'NP': {}}, 'VP': {'VV': {}, ',': {}, 'IP': {}}, '.': {}}}: 0.0004
# {'IP': {'NP': {'PRP': {}}, 'VP': {'VV': {}, 'AS': {}, 'NP': {}}, '.': {}}}: 0.0004
# ['NOUN', 'PROPN', 'clf']: 0.0004
# ['PRON', 'PART', 'compound']: 0.0004
# ['PART', 'VERB', 'nsubj:pass']: 0.0004
# ['PART', 'VERB', 'obl:patient']: 0.0004
# ['ADJ', 'ADJ', 'xcomp']: 0.0004
# ['PRON', 'ROOT', 'root']: 0.0004
# ['ADJ', 'NOUN', 'conj']: 0.0004
# {'IP': {'ADVP': {}, 'PP': {}, ',': {}, 'NP': {}, 'VP': {}}}: 0.0004
# ['PROPN', 'PART', 'nsubj']: 0.0004
# {'IP': {'``': {}, 'IP': {}, '.': {}}}: 0.0004
# ['VERB', 'ADP', 'xcomp']: 0.0004
# ['VERB', 'NOUN', 'advcl']: 0.0004
# ['VERB', 'PART', 'amod']: 0.0004
# {'IP': {'ADVP': {}, ',': {}, 'PP': {}, ',': {}, 'NP': {}, 'VP': {}}}: 0.0004
# ['NOUN', 'NOUN', 'compound']: 0.0004
# ['VERB', 'PART', 'parataxis']: 0.0004
# ['ADJ', 'NOUN', 'nmod']: 0.0003
# ['PART', 'PROPN', 'nmod']: 0.0003
# ['PART', 'NUM', 'case']: 0.0003
# {'NP': {'QP': {}, 'NP': {}, 'NP': {}}}: 0.0003
# ['NOUN', 'ADP', 'nmod']: 0.0003
# ['PART', 'PROPN', 'mark:rel']: 0.0003
# {'ADVP': {'JJ': {}}}: 0.0003
# ['AUX', 'PART', 'aux']: 0.0003
# {'IP': {'ADVP': {}, ',': {}, 'IP': {}, ',': {}, 'NP': {}, 'VP': {}, '.': {}}}: 0.0003
# ['CCONJ', 'PRON', 'cc']: 0.0003
# {'IP': {'NP': {'NP': {}, 'NP': {}}, 'VP': {'NP': {}, 'VP': {}}, '.': {}}}: 0.0003
# {'IP': {'NP': {'QP': {}, 'NP': {}}, 'VP': {'VV': {}, ',': {}, 'IP': {}}, '.': {}}}: 0.0003
# ['VERB', 'NOUN', 'xcomp']: 0.0003
# ['NOUN', 'VERB', 'conj']: 0.0003
# ['NOUN', 'NUM', 'clf']: 0.0003
# ['NUM', 'VERB', 'parataxis']: 0.0003
# {'VP': {'MD': {}, 'IP': {}}}: 0.0003
# ['VERB', 'NOUN', 'ccomp']: 0.0003
# ['X', 'ADJ', 'nsubj']: 0.0003
# ['PART', 'PROPN', 'appos']: 0.0003
# {'IP': {'IP': {}, 'NP': {}, 'VP': {}, '.': {}}}: 0.0003
# {'IP': {'ADVP': {}, 'ADVP': {}, ',': {}, 'NP': {}, 'VP': {}}}: 0.0003
# {'IP': {'NP': {'NNP': {}}, 'VP': {'MD': {}, 'VP': {}}, '.': {}}}: 0.0003
# ['X', 'NOUN', 'nsubj']: 0.0003
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ',': {}, 'IP': {'PP': {}, ',': {}, 'NP': {}, 'VP': {}}, '.': {}}}: 0.0003
# ['PROPN', 'PRON', 'nmod']: 0.0003
# ['ADJ', 'ADJ', 'amod']: 0.0003
# {'VP': {'ADVP': {}, 'ADVP': {}, 'PP': {}, 'VP': {}}}: 0.0003
# ['ADJ', 'ADJ', 'parataxis']: 0.0003
# ['PROPN', 'VERB', 'nsubj:pass']: 0.0003
# ['PART', 'X', 'mark:rel']: 0.0003
# ['NUM', 'ROOT', 'root']: 0.0003
# ['ADV', 'AUX', 'advmod']: 0.0003
# ['PART', 'VERB', 'discourse:sp']: 0.0003
# ['NOUN', 'PRON', 'conj']: 0.0003
# ['NOUN', 'NUM', 'nsubj']: 0.0003
# ['PART', 'DET', 'mark:rel']: 0.0003
# ['PART', 'VERB', 'xcomp']: 0.0003
# {'IP': {'IP': {'PP': {}, ',': {}, 'NP': {}, 'VP': {}}, ',': {}, 'IP': {'VP': {}}, '.': {}}}: 0.0003
# ['PART', 'NOUN', 'appos']: 0.0003
# ['PRON', 'VERB', 'ccomp']: 0.0003
# ['NOUN', 'ADJ', 'parataxis']: 0.0003
# ['ADJ', 'VERB', 'obj']: 0.0003
# {'IP': {'IP': {'``': {}, 'NP': {}, 'VP': {}}, ',': {}, "''": {}, 'NP': {'NNP': {}}, 'VP': {'VV': {}}, '.': {}}}: 0.0003
# ['AUX', 'X', 'cop']: 0.0003
# ['ADJ', 'PART', 'acl:relcl']: 0.0003
# ['NOUN', 'NOUN', 'obl']: 0.0003
# ['PART', 'NOUN', 'amod']: 0.0003
# ['PROPN', 'VERB', 'ccomp']: 0.0003
# ['AUX', 'AUX', 'aux']: 0.0002
# {'IP': {'ADVP': {'RB': {}}, 'NP': {'PRP': {}}, 'VP': {'ADVP': {}, 'VP': {}}, '.': {}}}: 0.0002
# ['DET', 'NOUN', 'nsubj']: 0.0002
# {'IP': {'NP': {'PRD': {}}, 'VP': {'VP': {}, ',': {}, 'VP': {}}, '.': {}}}: 0.0002
# ['PART', 'VERB', 'nmod:tmod']: 0.0002
# ['NUM', 'NOUN', 'nsubj']: 0.0002
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ',': {}, 'IP': {'NP': {}, 'NP': {}, 'VP': {}}, '.': {}}}: 0.0002
# ['PART', 'VERB', 'advcl']: 0.0002
# {'IP': {'NP': {'QP': {}, 'NP': {}}, 'VP': {'ADVP': {}, 'VP': {}}, '.': {}}}: 0.0002
# ['ADP', 'ADV', 'case']: 0.0002
# {'IP': {'NP': {'NNP': {}, 'NN': {}}, 'VP': {'VV': {}, ',': {}, 'IP': {}}, '.': {}}}: 0.0002
# {'IP': {'CP': {}, ',': {}, 'ADVP': {}, 'NP': {}, 'VP': {}}}: 0.0002
# ['PRON', 'AUX', 'nsubj']: 0.0002
# ['PART', 'X', 'case']: 0.0002
# {'IP': {'``': {}, 'IP': {}, ',': {}, 'IP': {}, '.': {}}}: 0.0002
# ['NOUN', 'PRON', 'acl']: 0.0002
# ['PART', 'ADJ', 'case']: 0.0002
# ['NUM', 'VERB', 'ccomp']: 0.0002
# {'LCP': {'VP': {}, 'IN': {}}}: 0.0002
# ['NOUN', 'X', 'clf']: 0.0002
# ['PROPN', 'ADP', 'nmod']: 0.0002
# ['PART', 'VERB', 'parataxis']: 0.0002
# ['NOUN', 'PRON', 'appos']: 0.0002
# ['ADJ', 'NOUN', 'acl']: 0.0002
# ['NUM', 'NOUN', 'amod']: 0.0002
# ['CCONJ', 'X', 'cc']: 0.0002
# {'PP': {'IN': {}, 'IP': {}, '.': {}}}: 0.0002
# {'IP': {'CP': {}, ',': {}, 'ADVP': {}, 'VP': {}, '.': {}}}: 0.0002
# ['NUM', 'NUM', 'conj']: 0.0002
# ['ADJ', 'ADJ', 'ccomp']: 0.0002
# ['NUM', 'NOUN', 'det']: 0.0002
# ['ADV', 'PART', 'mark']: 0.0002
# {'IP': {'CP': {}, ',': {}, 'ADVP': {}, 'VP': {}}}: 0.0002
# {'NP': {'NNP': {}, 'CC': {}, 'NNP': {}}}: 0.0002
# ['NOUN', 'PRON', 'nmod']: 0.0002
# ['ADV', 'PROPN', 'advmod']: 0.0002
# ['DET', 'VERB', 'obj']: 0.0002
# ['PART', 'NOUN', 'mark:adv']: 0.0002
# ['ADV', 'PROPN', 'mark']: 0.0002
# ['X', 'X', 'conj']: 0.0002
# {'VP': {'LCP': {}, ',': {}, 'VP': {}}}: 0.0002
# ['PROPN', 'NUM', 'nmod']: 0.0002
# {'NP': {'NP': {}, 'CP': {}, 'NP': {}}}: 0.0002
# ['VERB', 'PRON', 'acl:relcl']: 0.0002
# ['PART', 'AUX', 'mark:rel']: 0.0002
# ['PRON', 'ADJ', 'obl']: 0.0002
# ['NOUN', 'X', 'nsubj']: 0.0002
# ['PART', 'NUM', 'nsubj']: 0.0002
# {'IP': {'IP': {'PP': {}, ',': {}, 'NP': {}, 'VP': {}}, ',': {}, 'IP': {'ADVP': {}, 'NP': {}, 'VP': {}}, '.': {}}}: 0.0002
# ['PRON', 'PRON', 'nsubj']: 0.0002
# ['PUNCT', 'DET', 'punct']: 0.0002
# ['PROPN', 'ADJ', 'obl']: 0.0002
# {'IP': {'NP': {'CP': {}, 'NP': {}}, 'VP': {'VV': {}, ',': {}, 'IP': {}}, '.': {}}}: 0.0002
# ['NUM', 'PROPN', 'nummod']: 0.0002
# ['PART', 'PART', 'nsubj']: 0.0002
# ['VERB', 'PART', 'acl']: 0.0002
# ['PUNCT', 'ADP', 'punct']: 0.0002
# {'IP': {'IP': {}, ',': {}, 'ADVP': {}, 'NP': {}, 'VP': {}}}: 0.0002
# ['X', 'X', 'nmod']: 0.0002
# ['AUX', 'ROOT', 'root']: 0.0002
# {'IP': {'IP': {}, ',': {}, "''": {}, 'IP': {}, '.': {}}}: 0.0002
# ['AUX', 'VERB', 'ccomp']: 0.0002
# {'IP': {'NP': {'FW': {}}, 'VP': {'VV': {}, ',': {}, 'IP': {}}, '.': {}}}: 0.0002
# ['ADJ', 'NOUN', 'parataxis']: 0.0002
# {'IP': {'CP': {'ADVP': {}, 'IP': {}}, ',': {}, 'ADVP': {'RB': {}}, 'VP': {'ADVP': {}, 'VP': {}}, '.': {}}}: 0.0002
# ['NOUN', 'X', 'appos']: 0.0002
# ['NOUN', 'PROPN', 'nsubj']: 0.0002
# ['ADP', 'ADJ', 'mark']: 0.0001
# ['ADJ', 'NOUN', 'compound']: 0.0001
# ['VERB', 'NOUN', 'compound']: 0.0001
# ['NOUN', 'VERB', 'nmod']: 0.0001
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ',': {}, 'IP': {'NP': {}, 'VP': {}}, '.': {}, "''": {}}}: 0.0001
# {'PP': {'IN': {}, 'IP': {'NP': {}, 'VP': {}}, '.': {}}}: 0.0001
# ['ADJ', 'ADJ', 'advmod']: 0.0001
# ['NOUN', 'NOUN', 'advcl']: 0.0001
# ['ADV', 'DET', 'advmod']: 0.0001
# ['VERB', 'PART', 'conj']: 0.0001
# {'VP': {'VRD': {}, 'IP': {}}}: 0.0001
# ['ADJ', 'PROPN', 'amod']: 0.0001
# ['PART', 'NUM', 'nmod']: 0.0001
# ['PUNCT', 'PUNCT', 'punct']: 0.0001
# ['PART', 'PART', 'appos']: 0.0001
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ',': {}, 'CP': {'ADVP': {}, 'IP': {}}, '.': {}}}: 0.0001
# ['ADV', 'AUX', 'mark']: 0.0001
# {'IP': {'NP': {'NNP': {}}, 'VP': {'VV': {}, ':': {}, 'IP': {}}, '.': {}, "''": {}}}: 0.0001
# {'IP': {'IP': {}, ',': {}, "''": {}}}: 0.0001
# {'IP': {'IP': {'PP': {}, ',': {}, 'NP': {}, 'VP': {}}, ',': {}, 'IP': {'PP': {}, ',': {}, 'NP': {}, 'VP': {}}, '.': {}}}: 0.0001
# {'NP': {'FW': {}, 'NN': {}}}: 0.0001
# ['NOUN', 'NOUN', 'amod']: 0.0001
# ['DET', 'DET', 'flat:foreign']: 0.0001
# ['NUM', 'NOUN', 'appos']: 0.0001
# ['NOUN', 'NOUN', 'obj']: 0.0001
# {'IP': {'PP': {}, ',': {}, 'NP': {}, 'VP': {}, '.': {}, "''": {}}}: 0.0001
# ['NUM', 'NOUN', 'compound']: 0.0001
# ['VERB', 'NOUN', 'nmod']: 0.0001
# ['X', 'DET', 'flat:foreign']: 0.0001
# ['ADJ', 'PROPN', 'acl:relcl']: 0.0001
# ['PART', 'VERB', 'case']: 0.0001
# ['X', 'PROPN', 'flat:name']: 0.0001
# ['PUNCT', 'NOUN', 'nmod']: 0.0001
# ['PRON', 'VERB', 'iobj']: 0.0001
# {'IP': {'IP': {'``': {}, 'NP': {}, 'VP': {}}, ',': {}, "''": {}, 'NP': {'PRP': {}}, 'VP': {'VV': {}}, '.': {}}}: 0.0001
# ['X', 'PART', 'compound']: 0.0001
# ['NOUN', 'PART', 'nmod:tmod']: 0.0001
# ['VERB', 'NUM', 'parataxis']: 0.0001
# ['PRON', 'NUM', 'nsubj']: 0.0001
# ['PUNCT', 'NOUN', 'nummod']: 0.0001
# {'IP': {'ADVP': {}, ',': {}, 'NP': {}, ',': {}, 'NP': {}, 'VP': {}, '.': {}}}: 0.0001
# ['PART', 'ADJ', 'compound:ext']: 0.0001
# ['NOUN', 'ADJ', 'advcl']: 0.0001
# ['NOUN', 'PART', 'parataxis']: 0.0001
# {'IP': {'NP': {'NP': {}, 'NP': {}}, 'VP': {'VV': {}, ':': {}, 'IP': {}}, '.': {}, "''": {}}}: 0.0001
# ['AUX', 'PROPN', 'aux']: 0.0001
# ['NUM', 'VERB', 'nmod:tmod']: 0.0001
# ['PRON', 'PROPN', 'appos']: 0.0001
# {'IP': {'IP': {}, ':': {}, 'IP': {}, '.': {}, "''": {}}}: 0.0001
# {'NP': {'FW': {}, 'FW': {}}}: 0.0001
# ['NOUN', 'AUX', 'nsubj']: 0.0001
# ['PROPN', 'X', 'appos']: 0.0001
# ['NUM', 'ADJ', 'nsubj']: 0.0001
# ['NOUN', 'NUM', 'conj']: 0.0001
# ['PROPN', 'PRON', 'conj']: 0.0001
# ['PROPN', 'PART', 'conj']: 0.0001
# ['NUM', 'X', 'nummod']: 0.0001
# ['PROPN', 'NOUN', 'nummod']: 0.0001
# {'IP': {'IP': {}, ',': {}, 'IP': {}, ',': {}, 'PP': {}, '.': {}}}: 0.0001
# ['PART', 'ADJ', 'obj']: 0.0001
# ['NOUN', 'PROPN', 'acl:relcl']: 0.0001
# ['NUM', 'PART', 'nmod']: 0.0001
# ['PRON', 'NOUN', 'amod']: 0.0001
# ['VERB', 'AUX', 'advcl']: 0.0001
# ['NUM', 'NOUN', 'clf']: 0.0001
# ['PART', 'X', 'nmod']: 0.0001
# ['VERB', 'NOUN', 'appos']: 0.0001
# ['VERB', 'NUM', 'acl:relcl']: 0.0001
# ['NUM', 'NUM', 'nmod']: 0.0001
# ['PART', 'NOUN', 'acl']: 0.0001
# ['VERB', 'PRON', 'csubj']: 0.0001
# ['ADP', 'ROOT', 'root']: 0.0001
# ['PROPN', 'VERB', 'advcl']: 0.0001
# ['NOUN', 'X', 'conj']: 0.0001
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ':': {}, 'IP': {'NP': {}, 'VP': {}}, '.': {}}}: 0.0001
# ['PUNCT', 'VERB', 'obj']: 0.0001
# ['PART', 'PART', 'discourse']: 0.0001
# ['NUM', 'ADJ', 'nummod']: 0.0000
# ['NOUN', 'X', 'acl']: 0.0000
# ['PROPN', 'ADJ', 'obj']: 0.0000
# ['NUM', 'VERB', 'advcl']: 0.0000
# ['PART', 'ADV', 'mark:adv']: 0.0000
# ['VERB', 'AUX', 'xcomp']: 0.0000
# ['PRON', 'PRON', 'nmod']: 0.0000
# ['PUNCT', 'PART', 'compound']: 0.0000
# ['NOUN', 'NUM', 'acl']: 0.0000
# ['PROPN', 'X', 'conj']: 0.0000
# ['PART', 'PART', 'acl']: 0.0000
# ['X', 'PROPN', 'flat:foreign']: 0.0000
# ['VERB', 'NUM', 'dislocated']: 0.0000
# ['NUM', 'PART', 'compound']: 0.0000
# ['NOUN', 'PROPN', 'obj']: 0.0000
# ['NOUN', 'PROPN', 'flat:name']: 0.0000
# ['ADP', 'PUNCT', 'case']: 0.0000
# ['PROPN', 'VERB', 'nmod:tmod']: 0.0000
# ['PART', 'PART', 'parataxis']: 0.0000
# {'IP': {'NP': {'FW': {}}, 'VP': {'VV': {}, ':': {}, 'IP': {}}, '.': {}, "''": {}}}: 0.0000
# {'NP': {'NNP': {}, '/': {}, 'NNP': {}, 'FW': {}, 'FW': {}}}: 0.0000
# ['PART', 'NOUN', 'parataxis']: 0.0000
# ['PUNCT', 'PART', 'nmod']: 0.0000
# ['SYM', 'NOUN', 'punct']: 0.0000
# {'IP': {'IP': {}, ',': {}, 'IP': {}, ',': {}, '.': {}}}: 0.0000
# ['PUNCT', 'VERB', 'obl']: 0.0000
# ['NOUN', 'NUM', 'obj']: 0.0000
# {'IP': {'ADVP': {}, 'NP': {}, 'VP': {}, 'NP': {}, 'VP': {}}}: 0.0000
# {'IP': {'NP': {}, 'VP': {}, 'NP': {}, 'VP': {}}}: 0.0000
# {'IP': {'IP': {}, ':': {}, 'IP': {}, ',': {}, '.': {}}}: 0.0000
# {'VP': {'VP': {}, ',': {}, 'VP': {}, ',': {}, 'RB': {}}}: 0.0000
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ',': {}, 'IP': {'NP': {}, 'VP': {}, 'NP': {}, 'VP': {}}, ',': {}, '.': {}}}: 0.0000
# {'VP': {'VP': {}, ',': {}, 'VP': {}, ',': {}}}: 0.0000
# {'IP': {'VP': {}, 'NP': {}, 'VP': {}}}: 0.0000
# {'IP': {'IP': {}, ',': {}, 'IP': {}, ':': {}, '.': {}}}: 0.0000
# {'NP': {'CD': {}, 'CD': {}, 'NNB': {}, 'NNB': {}}}: 0.0000
# {'IP': {'IP': {'PP': {}, ',': {}, 'NP': {}, 'VP': {}}, ',': {}, 'IP': {'NP': {}, 'VP': {}, 'NP': {}, 'VP': {}}, ',': {}, '.': {}}}: 0.0000
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ',': {}, 'IP': {'NP': {}, 'VP': {}, 'ADVP': {}, 'NP': {}, 'VP': {}}, ',': {}, '.': {}}}: 0.0000
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ',': {}, 'IP': {'VP': {}, 'NP': {}, 'VP': {}}, ',': {}, '.': {}}}: 0.0000
# {'IP': {'IP': {}, ',': {}, 'IP': {}, ',': {}, '.': {}, "''": {}}}: 0.0000
# {'IP': {'IP': {}, ',': {}, 'IP': {}, ',': {}, 'RB': {}, '.': {}}}: 0.0000
# {'NP': {'NNP': {}, 'NN': {}, 'NN': {}, 'VV': {}, 'SFN': {}}}: 0.0000
# {'IP': {'NP': {'PRP': {}}, 'VP': {'VP': {}, ',': {}, 'VP': {}, ',': {}}, '.': {}}}: 0.0000
# {'IP': {'IP': {}, ',': {}, 'IP': {}, ',': {}}}: 0.0000
# {'IP': {'NP': {}, 'VP': {}, 'VP': {}}}: 0.0000
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ',': {}, 'IP': {'ADVP': {}, 'NP': {}, 'VP': {}, 'NP': {}, 'VP': {}}, ',': {}, '.': {}}}: 0.0000
# {'NP': {'CD': {}, 'NNB': {}, 'NNB': {}, 'CD': {}}}: 0.0000
# {'IP': {'NP': {}, 'VP': {}, 'ADVP': {}, 'NP': {}, 'VP': {}}}: 0.0000
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7380\867364055.py:17: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   plt.tight_layout()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7380\867364055.py:17: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   plt.tight_layout()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7380\867364055.py:17: UserWarning: Glyph 21517 (\N{CJK UNIFIED IDEOGRAPH-540D}) missing from current font.
#   plt.tight_layout()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7380\867364055.py:17: UserWarning: Glyph 31216 (\N{CJK UNIFIED IDEOGRAPH-79F0}) missing from current font.
#   plt.tight_layout()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7380\867364055.py:17: UserWarning: Glyph 37325 (\N{CJK UNIFIED IDEOGRAPH-91CD}) missing from current font.
#   plt.tight_layout()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7380\867364055.py:17: UserWarning: Glyph 35201 (\N{CJK UNIFIED IDEOGRAPH-8981}) missing from current font.
#   plt.tight_layout()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7380\867364055.py:17: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   plt.tight_layout()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7380\867364055.py:17: UserWarning: Glyph 24471 (\N{CJK UNIFIED IDEOGRAPH-5F97}) missing from current font.
#   plt.tight_layout()
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7380\867364055.py:17: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   plt.tight_layout()
# c:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 37325 (\N{CJK UNIFIED IDEOGRAPH-91CD}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 35201 (\N{CJK UNIFIED IDEOGRAPH-8981}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 24471 (\N{CJK UNIFIED IDEOGRAPH-5F97}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 21517 (\N{CJK UNIFIED IDEOGRAPH-540D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\Administrator\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 31216 (\N{CJK UNIFIED IDEOGRAPH-79F0}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# orig build vec
# ed
with open('./all_feature_index.json', 'r', encoding='utf-8') as f:
    updated_data = json.load(f)
result_vec = []
dic_re = []
for file in tqdm(list_txt_files("./LCMC_txt"), total=3, desc="Processing", unit="file"):
    with open(file, "r", encoding="utf-8") as file:
        for line in file:
            if line == "":
                doc = nlp(line)
                l1 = [0] * 629
                dict_ft_txt = {}
                # Constituency
                m = str(doc.sentences[0].constituency)
                result = build_constituency_feature_tree(m, 2)
                ff = extract_constituency_feature_from_tree(result)
                for item in ff:
                    if item in updated_data:
                        l1[updated_data[item]] += 1
                        dict_ft_txt[updated_data[item]] = item
                result = build_constituency_feature_tree(m, 3)
                ff = extract_constituency_feature_from_tree(result)
                for item in ff:
                    if item in updated_data:
                        l1[updated_data[item]] += 1
                        dict_ft_txt[updated_data[item]] = item
            
                # Dependency
                words = doc.sentences[0].words
                dependency_list = extract_dependency_feature_from_list(words)
                for dep in dependency_list:
                    if dep[0] in updated_data:
                        l1[updated_data[dep[0]]] += 1
                        dict_ft_txt[updated_data[dep[0]]] = dep[1]
                dic_re.append(dict_ft_txt)
                result_vec.append(l1)

# %%
#index orig feature 
#sy
# ed
with open('./all_feature.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

#TODO: 检查data是否是字典

# 遍历字典，将值改为递增的索引
updated_data = {}
for index, key in enumerate(data.keys()):
    updated_data[key] = index

# 写入新的 JSON 文件
with open('./all_feature_index.json', 'w', encoding='utf-8') as f:
    json.dump(updated_data, f, ensure_ascii=False, indent=4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 3
#       1 #index orig feature
#       2 #sy
# ----> 3 with open('./all_feature.json', 'r', encoding='utf-8') as f:
#       4     data = json.load(f)
#       6 #TODO: 检查data是否是字典
#       7
#       8 # 遍历字典，将值改为递增的索引
#
# File ~/anaconda3/envs/yshi/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './all_feature.json'

# %%
feature_count_map = defaultdict(int)

# %%
#instruct提取成分句法
# ed
i = 0
for file in tqdm(list_txt_files("./instruct_txt"), total=88, desc="Processing", unit="file"):
    ll = []
    with open(file, "r", encoding="utf-8") as file:
        for line in file:
            ll.append(line)
            doc = nlp(line)
        
            # Constituency
            m = str(doc.sentences[0].constituency)
            ll.append(m)
            result = build_constituency_feature_tree(m, 2)
            ll.append("layer 2:")
            ff = extract_constituency_feature_from_tree(result)
            for item in ff:
                ll.append(item)
                feature_sentences_map[item].append(line)
            result = build_constituency_feature_tree(m, 3)
            ll.append("layer 3:")
            ff = extract_constituency_feature_from_tree(result)
            for item in ff:
                ll.append(item)
                feature_sentences_map[item].append(line)
        
            # Dependency
            words = doc.sentences[0].words
            dependency_list = extract_dependency_feature_from_list(words)
            ll.append("Dependency Features:")
            for dep in dependency_list:
                ll.append(dep)  # 用制表符拼接特征
        
            ll.append("----------------------------------------------------------------------")
    
            with open(f'./tmp/feature{i}.txt', 'w', encoding='utf-8') as f:
                f.write('\n'.join(ll))
        i+=1

# %%
feature_sentences_map = defaultdict(list)

# %%
#orig building tmp
i = 0
for file in tqdm(list_txt_files("./LCMC_txt"), total=3, desc="Processing", unit="file"):
    ll = []
    with open(file, "r", encoding="utf-8") as file:
        for line in file:
            if line != '\n':
                ll.append(line)
                doc = nlp(line)
        
                # Constituency
                m = str(doc.sentences[0].constituency)
                ll.append(m)
                result = build_constituency_feature_tree(m, 2)
                ll.append("layer 2:")
                ff = extract_constituency_feature_from_tree(result)
                for item in ff:
                    ll.append(item)
                    # feature_sentences_map[item].append(line)
                result = build_constituency_feature_tree(m, 3)
                ll.append("layer 3:")
                ff = extract_constituency_feature_from_tree(result)
                for item in ff:
                    ll.append(item)
                    # feature_sentences_map[item].append(line)
            
                # Dependency
                words = doc.sentences[0].words
                dependency_list = extract_dependency_feature_from_list(words)
                ll.append("Dependency Features:")
                for dep in dependency_list:
                    ll.append(str(dep))  # 用制表符拼接特征
            
                ll.append("----------------------------------------------------------------------")
        
    with open(f'./orig_tmp/feature{i}.txt', 'w', encoding='utf-8') as f:
        f.write('\n'.join(ll))
    i+=1
# Out:
# Processing: 100%|██████████| 3/3 [21:46<00:00, 435.34s/file]

# %%
#提取成分句法
# zcy add Time: 2025.01.16

Dependency_feature_count_map = defaultdict(int)
for file in tqdm(list_txt_files("./instruct_txt"), total=88, desc="Processing", unit="file"):
    with open(file, "r", encoding="utf-8") as file:
        for line in file:
            doc = nlp(line)
        
            # Dependency
            words = doc.sentences[0].words
            dependency_list = extract_dependency_feature_from_list(words)
            for dep in dependency_list:
                Dependency_feature_count_map[dep[0]] += 1
sorted_data = dict(sorted(Dependency_feature_count_map.items(), key=lambda item: item[1], reverse=True))

with open(f'./dependency_feature_count.json', 'w', encoding='utf-8') as f:
    json.dump(sorted_data, f, ensure_ascii=False, indent=4)
# Out:
# Processing: 100%|██████████| 88/88 [10:40<00:00,  7.28s/file]

# %%
# zcy add Time: 2025.01.16
# 读取 JSON 文件
with open('./all_feature.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

#TODO: 检查data是否是字典

# 遍历字典，将值改为递增的索引
updated_data = {}
for index, key in enumerate(data.keys()):
    updated_data[key] = index

# 写入新的 JSON 文件
with open('./all_feature_index.json', 'w', encoding='utf-8') as f:
    json.dump(updated_data, f, ensure_ascii=False, indent=4)

# %%
# zcy add Time: 2025.01.16

with open('./all_feature_index.json', 'r', encoding='utf-8') as f:
    updated_data = json.load(f)
result_vec = []
dic_re = []
for file in tqdm(list_txt_files("./instruct_txt"), total=88, desc="Processing", unit="file"):
    with open(file, "r", encoding="utf-8") as file:
        for line in file:
            doc = nlp(line)
            l1 = [0] * 629
            dict_ft_txt = {}
            # Constituency
            m = str(doc.sentences[0].constituency)
            result = build_constituency_feature_tree(m, 2)
            ff = extract_constituency_feature_from_tree(result)
            for item in ff:
                if item in updated_data:
                    l1[updated_data[item]] += 1
                    dict_ft_txt[updated_data[item]] = item
            result = build_constituency_feature_tree(m, 3)
            ff = extract_constituency_feature_from_tree(result)
            for item in ff:
                if item in updated_data:
                    l1[updated_data[item]] += 1
                    dict_ft_txt[updated_data[item]] = item
        
            # Dependency
            words = doc.sentences[0].words
            dependency_list = extract_dependency_feature_from_list(words)
            for dep in dependency_list:
                if dep[0] in updated_data:
                    l1[updated_data[dep[0]]] += 1
                    dict_ft_txt[updated_data[dep[0]]] = dep[1]
            dic_re.append(dict_ft_txt)
            result_vec.append(l1)
# Out:
# Processing: 100%|██████████| 88/88 [11:11<00:00,  7.63s/file]

# %%
# zcy add Time: 2025.01.17
with open('all_line_feature.json', 'w', encoding='utf-8') as f:
    json.dump(dic_re, f, ensure_ascii=False, indent=4)

# %%
# zcy add Time: 2025.01.17
with open("./all_line_vec.txt", "w", encoding="utf-8") as file:
    for row in result_vec:
        file.write(str(row) + "\n")  # 将每行写入，并添加换行符

# %%
#lemma是当前token
sent = '这并不一定是坏事，尤其是它向日本和韩国这两个盟友发出了几个至关重要的信息。'
doc = nlp(sent)
# print(doc.sentences[0])
for i in doc.sentences[0].words:
    head_id = i.head
    print(i.lemma, doc.sentences[0].words[head_id-1].lemma, i.deprel)
# Out:
# 这 是 nsubj
# 并 坏事 mark
# 不 坏事 advmod
# 一定 坏事 advmod
# 是 坏事 cop
# 坏事 是 advcl
# ， 坏事 punct
# 尤其 是 advmod
# 是 。 root
# 它 发出 nsubj
# 向 日本 case
# 日本 发出 obl
# 和 韩国 cc
# 韩国 日本 conj
# 这 个 det
# 两 个 nummod
# 个 盟友 nmod
# 盟友 发出 obl
# 发出 是 ccomp
# 了 发出 aux
# 几 个 nummod
# 个 信息 clf
# 至关重要 信息 amod
# 的 至关重要 mark:rel
# 信息 发出 obj
# 。 是 punct

# %%
# test提取依存树 暂时不用，好像错删了什么
def extract_dependency_feature_from_list(dependency_list):
    #lemma是当前token
    sent = '这并不一定是坏事，尤其是它向日本和韩国这两个盟友发出了几个至关重要的信息。'
    doc = nlp(sent)
# print(doc.sentences[0])
    for i in doc.sentences[0].words:
        head_id = i.head
        print(i.lemma, doc.sentences[0].words[head_id-1].lemma, i.deprel)
    
    # result = []
    # for dep in dependency_list:
    #     word = dep[0]
    #     head_word = dep[1]
    #     relation = dep[2]
    #     head_upos = head_word.upos
    #     result.append(f"{word.upos}/{head_upos}/{relation} {word.text}/{head_word.text if head_word else 'ROOT'}/{relation}")
    # return result

# 测试构造 tmp/test_feature.txt
ll = []
feature_sentences_map = defaultdict(list)
with open('./instruct_txt/A01A_en_zh.txt', "r", encoding="utf-8") as file:
    for line in file:
        ll.append(line.strip())
        doc = nlp(line)
        
        # Constituency tree
        if hasattr(doc.sentences[0], 'constituency'):
            m = str(doc.sentences[0].constituency)
            ll.append(m)
        else:
            ll.append("No constituency analysis available.")
            continue


        
        # Dependency tree
        # for sentence in doc.sentences:
        #     dependency_list = []
        #     for word in sentence.words:
        #         head_word = sentence.words[word.head - 1] if word.head > 0 else None
        #         dependency_list.append((word, head_word, word.deprel))
        #     ll.append("\n".join(extract_dependency_feature_from_list(dependency_list)))

        ll.append("----------------------------------------------------------------------")

# 输出到文件
with open('tmp/test_feature.txt', 'w', encoding='utf-8') as f:
    f.write('\n'.join(ll))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 34
#      32                 head_word = sentence.words[word.head - 1] if word.head > 0 else None
#      33                 dependency_list.append((word, head_word, word.deprel))
# ---> 34             ll.append("\n".join(extract_dependency_feature_from_list(dependency_list)))
#      36         ll.append("----------------------------------------------------------------------")
#      38 # 输出到文件
#
# Cell In[38], line 8, in extract_dependency_feature_from_list(dependency_list)
#       6     head_word = dep[1]
#       7     relation = dep[2]
# ----> 8     head_upos = head_word.upos
#       9     result.append(f"{word.upos}/{head_upos}/{relation} {word.text}/{head_word.text if head_word else 'ROOT'}/{relation}")
#      10 return result
#
# AttributeError: 'NoneType' object has no attribute 'upos'

# %%
sorted_data = dict(sorted(feature_count_map.items(), key=lambda item: item[1], reverse=True))
with open('feature_count.json', 'w', encoding='utf-8') as f:
    json.dump(sorted_data, f, ensure_ascii=False, indent=4)

# %%
sorted_sentences_data = dict(sorted(feature_sentences_map.items(), key=lambda item: len(item[1]), reverse=True))
with open('feature_sentences.json', 'w', encoding='utf-8') as f:
    json.dump(sorted_sentences_data, f, ensure_ascii=False, indent=4)

# %%
text_book = ['(ROOT (IP (IP (NP (NNP 平壤)) (VP (MD 可能) (VP (ADVP (RB 也)) (ADVP (RB 在)) (VP (VV 准备) (IP (VP (VV 试射) (NP (QP (CD 一) (CLP (NNB 枚))) (NP (NP (FW Taepo)) (FW Dong-2)) (NP (NN 导弹))))))))) (, ，) (IP (LCP (NP (NN 理论)) (IN 上)) (, ，) (NP (DP (DT 这) (CLP (NNB 种))) (NP (NN 导弹))) (VP (MD 可以) (VP (VP (VV 携带) (NP (NN 核弹) (SFN 头))) (, ，) (VP (VV 覆盖) (NP (DP (DT 整个)) (NP (NNP 美国)) (NP (NN 大陆))))))) (. 。)))']

result = build_constituency_feature_tree(text_book[0], 3)
print(result)

ff = extract_constituency_feature_from_tree(result)
for item in ff:
    print(item)
# Out:
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ',': {}, 'IP83738': {'LCP': {}, ',': {}, 'NP': {}, 'VP': {}}, '.': {}}}
# {'IP': {'IP': {'NP': {}, 'VP': {}}, ',': {}, 'IP': {'LCP': {}, ',': {}, 'NP': {}, 'VP': {}}, '.': {}}}
# {'IP': {'NP': {}, 'VP': {}}}
# {'IP': {'LCP': {}, ',': {}, 'NP': {}, 'VP': {}}}

# %%
print(extract_dependency_feature_from_list(m))
# Out:
# ['NOUN/NUM/nummod', 'VERB/NOUN/nsubj', 'VERB/ADV/mark', 'VERB/ADV/advmod', 'VERB/VERB/advcl', 'VERB/ADV/mark', 'None/VERB/root', 'VERB/AUX/aux', 'VERB/NOUN/nmod:tmod', 'VERB/VERB/xcomp', 'NOUN/NUM/nummod', 'VERB/NOUN/obj', 'VERB/PUNCT/punct']
